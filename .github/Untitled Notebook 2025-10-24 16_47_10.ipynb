# %%
import sys
sys.path.append('/Workspace/Repos/azjerry2023@outlook.com/Dbricks/tests')
import create_test_files

# %%
# %run /Workspace/Repos/azjerry2023@outlook.com/Dbricks/tests/create_test_files.py

# %%
# Cell 1: Add the tests folder to path
import sys
sys.path.append('/Workspace/Repos/azjerry2023@outlook.com/Dbricks/tests')

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
# Verify files exist
dbutils.fs.ls("abfss://rawdata@ucdatabricksstorage.dfs.core.windows.net/healthcare/payer/payments/")

# Drop new files
import sys
sys.path.append('/Workspace/Repos/azjerry2023@outlook.com/Dbricks/tests')
import create_test_files
create_test_files.create_all_test_files(account_name="ucdatabricksstorage")

# %%
# %sql
-- Check provider skew (80% to provider_123)
SELECT * FROM healthcare.default.gold_claims_837_summary LIMIT 100;
